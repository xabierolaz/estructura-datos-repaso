# %% [markdown]
# # Autotest diagnostico
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xabierolaz/estructura-datos-repaso/blob/main/autotest.ipynb)
#
# Flujo oficial del sistema:
#
# 1. `autotest.ipynb`
# 2. `resumen/`
# 3. `entrega/entrega_spyder.py`
#
# Este cuaderno no es una entrega y no se corrige automaticamente.

# %% [markdown]
# ## Como usar este cuaderno
#
# - antes de revelar una respuesta, escribe la tuya en la celda siguiente
# - marca honestamente si sale `sin_mirar`, `con_dudas` o `no_sale`
# - si un bloque sale flojo, vete a su `resumen/`
# - si un bloque sale limpio, pasa a `entrega/entrega_spyder.py`
# - este cuaderno diagnostica; no desarrolla la solucion completa

# %% [markdown]
# ## B01 - Fundamentos de Python
#
# Si este bloque no sale limpio, estudia [resumen B01](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/01_fundamentos_python/README.md).
# Si sale limpio, completa la seccion `B01` en [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 1. desempaquetado con estrella
#
# Tipo: `Lectura`
#
# <p>Sin ejecutar ni mirar apuntes, resuelve:</p><pre><code>first, *middle, last = [10, 20, 30, 40, 50]</code></pre><p>¿Qué valores toman <code>first</code>, <code>middle</code> y <code>last</code>?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b01_i1_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b01_i1_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b01_i1_respuesta.strip()
assert b01_i1_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b01_i1_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>first = 10</code>, <code>middle = [20, 30, 40]</code>, <code>last = 50</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B01](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/01_fundamentos_python/README.md).
# Si sale limpio, luego podras pasar a la seccion `B01` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 2. modo de apertura correcto
#
# Tipo: `Ficheros`
#
# <p>Quieres seguir escribiendo al final de un fichero sin borrar su contenido anterior. ¿Qué modo de apertura es el adecuado entre <code>r</code>, <code>w</code> y <code>a</code>?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b01_i2_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b01_i2_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b01_i2_respuesta.strip()
assert b01_i2_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b01_i2_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>a</code>.</p><p><code>w</code> trunca el fichero y <code>r</code> no es el modo para escribir al final.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B01](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/01_fundamentos_python/README.md).
# Si sale limpio, luego podras pasar a la seccion `B01` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 3. __name__ al importar
#
# Tipo: `Ejecucion`
#
# <p>Si un archivo Python se importa desde otro en lugar de ejecutarse directamente, ¿su <code>__name__</code> vale <code>"__main__"</code> o el nombre del módulo?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b01_i3_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b01_i3_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b01_i3_respuesta.strip()
assert b01_i3_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b01_i3_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> vale el nombre del módulo.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B01](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/01_fundamentos_python/README.md).
# Si sale limpio, luego podras pasar a la seccion `B01` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### Salida del bloque B01
#
# - si una o mas anclas han quedado en `con_dudas` o `no_sale`, estudia primero [resumen B01](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/01_fundamentos_python/README.md)
# - si el bloque sale limpio, abre [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py) y busca `===== B01 =====`
# - `python entrega/prueba.py --block B01` es solo una comprobacion local opcional

# %% [markdown]
# ## B02 - Clases y objetos
#
# Si este bloque no sale limpio, estudia [resumen B02](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/02_clases_y_objetos/README.md).
# Si sale limpio, completa la seccion `B02` en [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 1. clase frente a objeto
#
# Tipo: `Concepto`
#
# <p>Sin mirar apuntes: en OOP, ¿qué es la clase y qué es el objeto?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b02_i1_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b02_i1_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b02_i1_respuesta.strip()
assert b02_i1_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b02_i1_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> la clase es la plantilla o molde; el objeto es la instancia concreta creada a partir de esa plantilla.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B02](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/02_clases_y_objetos/README.md).
# Si sale limpio, luego podras pasar a la seccion `B02` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 2. que significa self
#
# Tipo: `Lectura de clase`
#
# <p>En el método <code>def depositar(self, cantidad):</code>, ¿qué representa <code>self</code>?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b02_i2_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b02_i2_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b02_i2_respuesta.strip()
assert b02_i2_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b02_i2_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> el objeto concreto sobre el que se está ejecutando el método.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B02](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/02_clases_y_objetos/README.md).
# Si sale limpio, luego podras pasar a la seccion `B02` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 3. control de acceso
#
# Tipo: `Diseño`
#
# <p>Si una clase usa <code>__saldo</code> como atributo, ¿qué idea de diseño se está marcando?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b02_i3_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b02_i3_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b02_i3_respuesta.strip()
assert b02_i3_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b02_i3_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> que el atributo es interno y que su acceso o modificación debería controlarse desde métodos de la clase.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B02](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/02_clases_y_objetos/README.md).
# Si sale limpio, luego podras pasar a la seccion `B02` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### Salida del bloque B02
#
# - si una o mas anclas han quedado en `con_dudas` o `no_sale`, estudia primero [resumen B02](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/02_clases_y_objetos/README.md)
# - si el bloque sale limpio, abre [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py) y busca `===== B02 =====`
# - `python entrega/prueba.py --block B02` es solo una comprobacion local opcional

# %% [markdown]
# ## B03 - ADT, stacks y queues
#
# Si este bloque no sale limpio, estudia [resumen B03](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/03_stacks_y_queues/README.md).
# Si sale limpio, completa la seccion `B03` en [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 1. ADT frente a implementacion
#
# Tipo: `Concepto`
#
# <p>¿Qué describe un ADT y qué deja sin fijar?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b03_i1_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b03_i1_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b03_i1_respuesta.strip()
assert b03_i1_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b03_i1_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> describe operaciones y comportamiento esperado; no fija la implementación concreta ni la representación exacta en memoria.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B03](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/03_stacks_y_queues/README.md).
# Si sale limpio, luego podras pasar a la seccion `B03` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
#             ### 2. trazado de stack
#
#             Tipo: `Trazado`
#
#             <p>En una stack vacía se hace:</p><pre><code>push(4)
# push(9)
# x = pop()
# y = peek()</code></pre><p>¿Qué valores deben quedar en <code>x</code> e <code>y</code>?</p>
#
#             Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b03_i2_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b03_i2_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b03_i2_respuesta.strip()
assert b03_i2_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b03_i2_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>x = 9</code> y <code>y = 4</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B03](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/03_stacks_y_queues/README.md).
# Si sale limpio, luego podras pasar a la seccion `B03` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
#             ### 3. trazado de queue
#
#             Tipo: `Trazado`
#
#             <p>En una queue vacía se hace:</p><pre><code>enqueue('A')
# enqueue('B')
# enqueue('C')
# x = dequeue()</code></pre><p>¿Qué valor sale en <code>x</code>?</p>
#
#             Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b03_i3_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b03_i3_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b03_i3_respuesta.strip()
assert b03_i3_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b03_i3_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>'A'</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B03](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/03_stacks_y_queues/README.md).
# Si sale limpio, luego podras pasar a la seccion `B03` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### Salida del bloque B03
#
# - si una o mas anclas han quedado en `con_dudas` o `no_sale`, estudia primero [resumen B03](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/03_stacks_y_queues/README.md)
# - si el bloque sale limpio, abre [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py) y busca `===== B03 =====`
# - `python entrega/prueba.py --block B03` es solo una comprobacion local opcional

# %% [markdown]
# ## B04 - Deque y priority queue
#
# Si este bloque no sale limpio, estudia [resumen B04](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/04_deque_priority_queue/README.md).
# Si sale limpio, completa la seccion `B04` en [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 1. operaciones por ambos extremos
#
# Tipo: `Concepto`
#
# <p>¿Qué hace que una <code>deque</code> sea más general que una queue normal?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b04_i1_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b04_i1_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b04_i1_respuesta.strip()
assert b04_i1_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b04_i1_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> que permite insertar y extraer por ambos extremos.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B04](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/04_deque_priority_queue/README.md).
# Si sale limpio, luego podras pasar a la seccion `B04` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
#             ### 2. collections.deque
#
#             Tipo: `Trazado`
#
#             <p>Si empiezas con una <code>deque</code> vacía y haces:</p><pre><code>append('b')
# appendleft('a')
# pop()</code></pre><p>¿Qué elemento queda dentro?</p>
#
#             Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b04_i2_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b04_i2_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b04_i2_respuesta.strip()
assert b04_i2_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b04_i2_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> queda <code>'a'</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B04](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/04_deque_priority_queue/README.md).
# Si sale limpio, luego podras pasar a la seccion `B04` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 3. donde pagas el coste
#
# Tipo: `Priority queue`
#
# <p>En una priority queue, ¿qué enfoque mantiene la estructura ordenada en el momento de insertar: inserción ordenada o búsqueda al extraer?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b04_i3_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b04_i3_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b04_i3_respuesta.strip()
assert b04_i3_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b04_i3_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> inserción ordenada.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B04](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/04_deque_priority_queue/README.md).
# Si sale limpio, luego podras pasar a la seccion `B04` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### Salida del bloque B04
#
# - si una o mas anclas han quedado en `con_dudas` o `no_sale`, estudia primero [resumen B04](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/04_deque_priority_queue/README.md)
# - si el bloque sale limpio, abre [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py) y busca `===== B04 =====`
# - `python entrega/prueba.py --block B04` es solo una comprobacion local opcional

# %% [markdown]
# ## B05 - Buffers circulares
#
# Si este bloque no sale limpio, estudia [resumen B05](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/05_buffers_circulares/README.md).
# Si sale limpio, completa la seccion `B05` en [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 1. buffer frente a queue
#
# Tipo: `Concepto`
#
# <p>¿Qué rasgo separa a un buffer de una queue pensada solo como ADT?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b05_i1_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b05_i1_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b05_i1_respuesta.strip()
assert b05_i1_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b05_i1_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> el buffer se define por su caso de uso y su capacidad/flujo de datos; la queue se define por sus reglas de acceso FIFO.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B05](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/05_buffers_circulares/README.md).
# Si sale limpio, luego podras pasar a la seccion `B05` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 2. buffer lleno
#
# Tipo: `Politica`
#
# <p>Si un buffer circular de capacidad 3 elimina siempre el dato más antiguo cuando está lleno, y recibe <code>1, 2, 3, 4</code>, ¿qué datos quedan dentro?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b05_i2_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b05_i2_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b05_i2_respuesta.strip()
assert b05_i2_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b05_i2_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> quedan <code>2, 3, 4</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B05](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/05_buffers_circulares/README.md).
# Si sale limpio, luego podras pasar a la seccion `B05` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 3. indice circular
#
# Tipo: `Indices`
#
# <p>Si la capacidad es 5 y un índice vale 4, ¿cuál será su siguiente valor tras aplicar <code>(indice + 1) % capacidad</code>?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b05_i3_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b05_i3_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b05_i3_respuesta.strip()
assert b05_i3_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b05_i3_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>0</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B05](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/05_buffers_circulares/README.md).
# Si sale limpio, luego podras pasar a la seccion `B05` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### Salida del bloque B05
#
# - si una o mas anclas han quedado en `con_dudas` o `no_sale`, estudia primero [resumen B05](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/05_buffers_circulares/README.md)
# - si el bloque sale limpio, abre [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py) y busca `===== B05 =====`
# - `python entrega/prueba.py --block B05` es solo una comprobacion local opcional

# %% [markdown]
# ## B06 - Linked lists
#
# Si este bloque no sale limpio, estudia [resumen B06](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/06_linked_lists/README.md).
# Si sale limpio, completa la seccion `B06` en [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 1. recorrido desde head
#
# Tipo: `Trazado`
#
# <p>Si <code>head</code> apunta a <code>9 -&gt; 4 -&gt; 7 -&gt; None</code> y haces dos saltos con <code>current = current.next</code>, ¿qué dato contiene el nodo final alcanzado?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b06_i1_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b06_i1_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b06_i1_respuesta.strip()
assert b06_i1_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b06_i1_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>7</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B06](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/06_linked_lists/README.md).
# Si sale limpio, luego podras pasar a la seccion `B06` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 2. insertar en cabeza
#
# Tipo: `Estado final`
#
# <p>Si la lista es <code>4 -&gt; 7 -&gt; None</code> y haces <code>new = Node(2, head)</code> seguido de <code>head = new</code>, ¿qué cadena queda accesible desde <code>head</code>?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b06_i2_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b06_i2_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b06_i2_respuesta.strip()
assert b06_i2_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b06_i2_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> <code>2 -&gt; 4 -&gt; 7 -&gt; None</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B06](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/06_linked_lists/README.md).
# Si sale limpio, luego podras pasar a la seccion `B06` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### 3. remove_tail
#
# Tipo: `Idea operativa`
#
# <p>Para implementar <code>remove_tail()</code> en una singly linked list, ¿por qué no basta con llegar al último nodo?</p>
#
# Antes de abrir la solucion, escribe tu respuesta y tu estado en la siguiente celda.

# %%
b06_i3_respuesta = """Escribe aqui tu respuesta antes de abrir el spoiler."""
b06_i3_estado = "sin_mirar"  # cambia a: sin_mirar / con_dudas / no_sale

assert b06_i3_respuesta.strip()
assert b06_i3_respuesta.strip() != "Escribe aqui tu respuesta antes de abrir el spoiler."
assert b06_i3_estado in {"sin_mirar", "con_dudas", "no_sale"}

# %% [markdown]
# <details>
# <summary>Ver respuesta esperada</summary>
#
# <p><strong>Respuesta esperada:</strong> porque hay que modificar el enlace del penúltimo nodo para que pase a apuntar a <code>None</code>.</p>
#
# </details>
#
# Si aqui has marcado `con_dudas` o `no_sale`, vuelve al [resumen de B06](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/06_linked_lists/README.md).
# Si sale limpio, luego podras pasar a la seccion `B06` de [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py).

# %% [markdown]
# ### Salida del bloque B06
#
# - si una o mas anclas han quedado en `con_dudas` o `no_sale`, estudia primero [resumen B06](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/resumen/06_linked_lists/README.md)
# - si el bloque sale limpio, abre [entrega/entrega_spyder.py](https://github.com/xabierolaz/estructura-datos-repaso/blob/main/entrega/entrega_spyder.py) y busca `===== B06 =====`
# - `python entrega/prueba.py --block B06` es solo una comprobacion local opcional

# %% [markdown]
# ## Cierre
#
# El diagnostico solo vale si has sido honesto al marcar tus respuestas.
# Si un bloque no sale limpio, no pases directamente a la entrega.
